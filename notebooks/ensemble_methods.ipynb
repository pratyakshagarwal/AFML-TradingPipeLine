# %%
from scipy.special import comb
N,p,k=100,1./3,3.
p_=0
# for i in range(0,int(N/k)+1):
#     p_+=comb(N,i)*p**i*(1-p)**(N-i)
# print(p,1-p_)

# %%
N, p, k, p_
# Out:
# (100, 0.3333333333333333, 3.0, 0)

# %%
for i in range(0,int(N/k)+1):
    p_+=comb(N,i)*p**i*(1-p)**(N-i)
    print(f"i: {i}, partial p_: {p_}")
# Out:
# i: 0, partial p_: 2.4596544265798566e-18
# i: 1, partial p_: 1.2544237575557267e-16
# i: 2, partial p_: 3.1692647286481445e-15
# i: 3, partial p_: 5.288502982589347e-14
# i: 4, partial p_: 6.55688681629993e-13
# i: 5, partial p_: 6.4426037389493474e-12
# i: 6, partial p_: 5.225568127606089e-11
# i: 7, partial p_: 3.5985777331095266e-10
# i: 8, partial p_: 2.1477949332637606e-09
# i: 9, partial p_: 1.1286140417467e-08
# i: 10, partial p_: 5.286561237059174e-08
# i: 11, partial p_: 2.2296345217882926e-07
# i: 12, partial p_: 8.5374294146771e-07
# i: 13, partial p_: 2.9886889052146904e-06
# i: 14, partial p_: 9.622271006857093e-06
# i: 15, partial p_: 2.8638539698231976e-05
# i: 16, partial p_: 7.91505034096965e-05
# i: 17, partial p_: 0.00020394476669684413
# i: 18, partial p_: 0.00049166487371999
# i: 19, partial p_: 0.0011125345783488836
# i: 20, partial p_: 0.002369795730222413
# i: 21, partial p_: 0.004764578876648183
# i: 22, partial p_: 0.009064303162276247
# i: 23, partial p_: 0.01635513999442809
# i: 24, partial p_: 0.028050857412671767
# i: 25, partial p_: 0.04582834788840194
# i: 26, partial p_: 0.0714689591514743
# i: 27, partial p_: 0.10660609310457303
# i: 28, partial p_: 0.1524098570077195
# i: 29, partial p_: 0.20926970185300664
# i: 30, partial p_: 0.2765538515865962
# i: 31, partial p_: 0.3525198270922607
# i: 32, partial p_: 0.4344206444343062
# i: 33, partial p_: 0.5188033047261082
